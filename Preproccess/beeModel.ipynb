# %%
import os

# %%
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualization and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# configures matplotlib to inline and will display graphs below the corresponding cell
# %matplotlib inline
style.use('fivethirtyeight')
sns.set(style='whitegrid', color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess
from keras.preprocessing.image import ImageDataGenerator

#libraries
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical

#for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

import tensorflow as tf
import random as rn

#manipulation of zipped images and getting numpy arrays of pixel values of images
import cv2
import numpy as np
from tqdm import tqdm
import os
from random import shuffle
from zipfile import ZipFile
from PIL import Image

# %%
X = []
Z = []
IMG_SIZE = 150
BEE_BLUEBERRY_DIR = '../bees/blueberrybees'
BEE_BUMBLE_DIR = '../bees/bumblebees'
BEE_CARPENTER_DIR = '../bees/carpenterbees'
BEE_HONEY_DIR = '../bees/honeybees'
BEE_MASON_DIR = '../bees/masonbees'
BEE_MINING_DIR = '../bees/miningbees'
BEE_WESTERNHONEY_DIR = '../bees/westernhoneybees'

# %%
def assign_label(img,bee_type):
    return bee_type

# %%
def make_train_data(bee_type, DIR):
    for img in tqdm(os.listdir(DIR)):
        label = assign_label(img, bee_type)
        path = os.path.join(DIR, img)
        ext = img[-4:]
        if (ext != '.jpg'):
            continue
        img = cv2.imread(path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Blueberry Bee', BEE_BLUEBERRY_DIR)
print(len(X))
# Out:
# 100%|██████████| 1211/1211 [00:02<00:00, 541.91it/s]
# 791

# %%
make_train_data('Bumblebee', BEE_BUMBLE_DIR)
print(len(X))
# Out:
# 100%|██████████| 784/784 [00:02<00:00, 371.53it/s]
# 1519

# %%
make_train_data('Carpenter Bee', BEE_CARPENTER_DIR)
print(len(X))
# Out:
# 100%|██████████| 633/633 [00:01<00:00, 418.61it/s]
# 2101

# %%
make_train_data('Honey Bee', BEE_HONEY_DIR)
print(len(X))
# Out:
# 100%|██████████| 806/806 [00:02<00:00, 326.10it/s]
# 2855

# %%
make_train_data('Mason Bee', BEE_MASON_DIR)
print(len(X))
# Out:
# 100%|██████████| 1748/1748 [00:03<00:00, 477.27it/s]
# 3994

# %%
make_train_data('Mining Bee', BEE_MINING_DIR)
print(len(X))
# Out:
# 100%|██████████| 1434/1434 [00:03<00:00, 472.17it/s]
# 4946

# %%
make_train_data('Western Honey Bees', BEE_WESTERNHONEY_DIR)
print(len(X))
# Out:
# 100%|██████████| 2026/2026 [00:03<00:00, 528.67it/s]
# 6165

# %%
def blur():
    for i in range(1, len(X)):
        X[i] = cv2.GaussianBlur(X[i], (5, 5), 0)

# %%
#visualize 10 random images with blurring preprocessing
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range(2):
        l=rn.randint(0,len(Z))
        ax[i, j].imshow(X[l])
        ax[i,j].set_title('Bee: '+Z[l])
plt.tight_layout()

# %%
# label encoding
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,15)
X=np.array(X)
X=X/255

# %%
#splitting into training and validation sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state = 42)

# %%
#inputting the random seeds
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %%
# Using CNN to start modelling

model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 

#model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
#model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(15, activation = "softmax"))

# %%
# Using a LR Annealer

batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %%
# data augmentation to pevent overfitting

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
# compiling the model & summary
model.compile(optimizer=Adam(lr=0.001),
              loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 31104)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               15925760
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 15)                7695
# =================================================================
# Total params: 16,009,775
# Trainable params: 16,009,775
# Non-trainable params: 0
# _________________________________________________________________

# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
# fitting training set and making predictions on the validation set
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# Epoch 1/50
# 36/36 [==============================] - 20s 552ms/step - loss: 2.0158 - accuracy: 0.2235 - val_loss: 1.8278 - val_accuracy: 0.2555
# Epoch 2/50
# 36/36 [==============================] - 19s 514ms/step - loss: 1.8058 - accuracy: 0.2850 - val_loss: 1.7718 - val_accuracy: 0.2944
# Epoch 3/50
# 36/36 [==============================] - 19s 515ms/step - loss: 1.7451 - accuracy: 0.3079 - val_loss: 1.7043 - val_accuracy: 0.3171
# Epoch 4/50
# 36/36 [==============================] - 19s 516ms/step - loss: 1.7153 - accuracy: 0.3406 - val_loss: 1.7028 - val_accuracy: 0.3385
# Epoch 5/50
# 36/36 [==============================] - 19s 516ms/step - loss: 1.6619 - accuracy: 0.3502 - val_loss: 1.7875 - val_accuracy: 0.3307
# Epoch 6/50
# 36/36 [==============================] - 18s 512ms/step - loss: 1.6488 - accuracy: 0.3617 - val_loss: 1.6575 - val_accuracy: 0.3658
# Epoch 7/50
# 36/36 [==============================] - 19s 515ms/step - loss: 1.5981 - accuracy: 0.3858 - val_loss: 1.6192 - val_accuracy: 0.3885
# Epoch 8/50
# 36/36 [==============================] - 19s 516ms/step - loss: 1.5712 - accuracy: 0.3938 - val_loss: 1.6043 - val_accuracy: 0.3917
# Epoch 9/50
# 36/36 [==============================] - 19s 515ms/step - loss: 1.5917 - accuracy: 0.3809 - val_loss: 1.6091 - val_accuracy: 0.3943
# Epoch 10/50
# 36/36 [==============================] - 19s 515ms/step - loss: 1.5442 - accuracy: 0.4129 - val_loss: 1.5303 - val_accuracy: 0.4170
# Epoch 11/50
# 36/36 [==============================] - 19s 515ms/step - loss: 1.4956 - accuracy: 0.4278 - val_loss: 1.5135 - val_accuracy: 0.4397
# Epoch 12/50
# 36/36 [==============================] - 18s 512ms/step - loss: 1.4908 - accuracy: 0.4311 - val_loss: 1.5415 - val_accuracy: 0.4423
# Epoch 13/50
# 36/36 [==============================] - 18s 513ms/step - loss: 1.5004 - accuracy: 0.4387 - val_loss: 1.4783 - val_accuracy: 0.4553
# Epoch 14/50
# 36/36 [==============================] - 19s 515ms/step - loss: 1.4585 - accuracy: 0.4465 - val_loss: 1.4812 - val_accuracy: 0.4637
# Epoch 15/50
# 36/36 [==============================] - 19s 521ms/step - loss: 1.4110 - accuracy: 0.4674 - val_loss: 1.4462 - val_accuracy: 0.4715
# Epoch 16/50
# 36/36 [==============================] - 19s 520ms/step - loss: 1.3870 - accuracy: 0.4832 - val_loss: 1.4381 - val_accuracy: 0.4591
# Epoch 17/50
# 36/36 [==============================] - 19s 518ms/step - loss: 1.4111 - accuracy: 0.4770 - val_loss: 1.3899 - val_accuracy: 0.4922
# Epoch 18/50
# 36/36 [==============================] - 19s 515ms/step - loss: 1.3518 - accuracy: 0.4939 - val_loss: 1.4299 - val_accuracy: 0.4767
# Epoch 19/50
# 36/36 [==============================] - 19s 519ms/step - loss: 1.3751 - accuracy: 0.4845 - val_loss: 1.3797 - val_accuracy: 0.4942
# Epoch 20/50
# 36/36 [==============================] - 19s 516ms/step - loss: 1.3065 - accuracy: 0.5139 - val_loss: 1.4212 - val_accuracy: 0.4961
# Epoch 21/50
# 36/36 [==============================] - 19s 523ms/step - loss: 1.2704 - accuracy: 0.5270 - val_loss: 1.3626 - val_accuracy: 0.5097
# Epoch 22/50
# 36/36 [==============================] - 19s 517ms/step - loss: 1.2717 - accuracy: 0.5226 - val_loss: 1.3571 - val_accuracy: 0.5097
# Epoch 23/50
# 36/36 [==============================] - 19s 519ms/step - loss: 1.2381 - accuracy: 0.5415 - val_loss: 1.3014 - val_accuracy: 0.5363
# Epoch 24/50
# 36/36 [==============================] - 19s 521ms/step - loss: 1.2092 - accuracy: 0.5522 - val_loss: 1.2802 - val_accuracy: 0.5493
# Epoch 25/50
# 36/36 [==============================] - 19s 519ms/step - loss: 1.1888 - accuracy: 0.5689 - val_loss: 1.2905 - val_accuracy: 0.5253
# Epoch 26/50
# 36/36 [==============================] - 19s 517ms/step - loss: 1.1578 - accuracy: 0.5773 - val_loss: 1.2676 - val_accuracy: 0.5597
# Epoch 27/50
# 36/36 [==============================] - 19s 516ms/step - loss: 1.1474 - accuracy: 0.5789 - val_loss: 1.2762 - val_accuracy: 0.5603
# Epoch 28/50
# 36/36 [==============================] - 18s 513ms/step - loss: 1.1349 - accuracy: 0.5898 - val_loss: 1.2620 - val_accuracy: 0.5545
# Epoch 29/50
# 36/36 [==============================] - 19s 514ms/step - loss: 1.0783 - accuracy: 0.6069 - val_loss: 1.2980 - val_accuracy: 0.5551
# Epoch 30/50
# 36/36 [==============================] - 18s 512ms/step - loss: 1.0450 - accuracy: 0.6256 - val_loss: 1.2389 - val_accuracy: 0.5629
# Epoch 31/50
# 36/36 [==============================] - 19s 515ms/step - loss: 1.0534 - accuracy: 0.6180 - val_loss: 1.3821 - val_accuracy: 0.5123
# Epoch 32/50
# 36/36 [==============================] - 18s 512ms/step - loss: 1.0164 - accuracy: 0.6374 - val_loss: 1.2460 - val_accuracy: 0.5759
# Epoch 33/50
# 36/36 [==============================] - 19s 515ms/step - loss: 0.9646 - accuracy: 0.6487 - val_loss: 1.1645 - val_accuracy: 0.6018
# Epoch 34/50
# 36/36 [==============================] - 19s 516ms/step - loss: 0.9515 - accuracy: 0.6554 - val_loss: 1.1882 - val_accuracy: 0.6128
# Epoch 35/50
# 36/36 [==============================] - 18s 512ms/step - loss: 0.9423 - accuracy: 0.6641 - val_loss: 1.1231 - val_accuracy: 0.6135
# Epoch 36/50
# 36/36 [==============================] - 19s 515ms/step - loss: 0.9040 - accuracy: 0.6759 - val_loss: 1.2054 - val_accuracy: 0.5999
# Epoch 37/50
# 36/36 [==============================] - 18s 512ms/step - loss: 0.8928 - accuracy: 0.6836 - val_loss: 1.0959 - val_accuracy: 0.6459
# Epoch 38/50
# 36/36 [==============================] - 19s 524ms/step - loss: 0.9122 - accuracy: 0.6730 - val_loss: 1.1355 - val_accuracy: 0.6206
# Epoch 39/50
# 36/36 [==============================] - 19s 534ms/step - loss: 0.9073 - accuracy: 0.6721 - val_loss: 1.0817 - val_accuracy: 0.6323
# Epoch 40/50
# 36/36 [==============================] - 19s 516ms/step - loss: 0.8066 - accuracy: 0.7190 - val_loss: 1.0660 - val_accuracy: 0.6556
# Epoch 41/50
# 36/36 [==============================] - 19s 515ms/step - loss: 0.8017 - accuracy: 0.7128 - val_loss: 1.0368 - val_accuracy: 0.6615
# Epoch 42/50
# 36/36 [==============================] - 19s 517ms/step - loss: 0.7602 - accuracy: 0.7210 - val_loss: 1.0833 - val_accuracy: 0.6563
# Epoch 43/50
# 36/36 [==============================] - 19s 516ms/step - loss: 0.8022 - accuracy: 0.7186 - val_loss: 1.1622 - val_accuracy: 0.6394
# Epoch 44/50
# 36/36 [==============================] - 18s 512ms/step - loss: 0.7332 - accuracy: 0.7453 - val_loss: 1.0381 - val_accuracy: 0.6783
# Epoch 45/50
# 36/36 [==============================] - 18s 513ms/step - loss: 0.7424 - accuracy: 0.7393 - val_loss: 0.9883 - val_accuracy: 0.6868
# Epoch 46/50
# 36/36 [==============================] - 19s 519ms/step - loss: 0.6903 - accuracy: 0.7631 - val_loss: 1.0299 - val_accuracy: 0.6881
# Epoch 47/50
# 36/36 [==============================] - 18s 507ms/step - loss: 0.6988 - accuracy: 0.7513 - val_loss: 1.0718 - val_accuracy: 0.6699
# Epoch 48/50
# 27/36 [=====================>........] - ETA: 4s - loss: 0.6684 - accuracy: 0.7580

# %%
# fitting training set and making prediction on the validation set
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# 36/36 [==============================] - 19s 518ms/step - loss: 0.5317 - accuracy: 0.8156 - val_loss: 1.0047 - val_accuracy: 0.7335
# Epoch 6/50
# 36/36 [==============================] - 19s 532ms/step - loss: 0.5756 - accuracy: 0.8018 - val_loss: 1.0990 - val_accuracy: 0.7062
# Epoch 7/50
# 36/36 [==============================] - 19s 527ms/step - loss: 0.5672 - accuracy: 0.8076 - val_loss: 1.0039 - val_accuracy: 0.7192
# Epoch 8/50
# 36/36 [==============================] - 20s 546ms/step - loss: 0.4990 - accuracy: 0.8296 - val_loss: 1.0433 - val_accuracy: 0.7114
# Epoch 9/50
# 36/36 [==============================] - 19s 531ms/step - loss: 0.5079 - accuracy: 0.8276 - val_loss: 1.0564 - val_accuracy: 0.7296
# Epoch 10/50
# 36/36 [==============================] - 19s 531ms/step - loss: 0.4868 - accuracy: 0.8289 - val_loss: 1.0067 - val_accuracy: 0.7451
# Epoch 11/50
# 36/36 [==============================] - 19s 534ms/step - loss: 0.4618 - accuracy: 0.8485 - val_loss: 1.0039 - val_accuracy: 0.7451
# Epoch 12/50
# 36/36 [==============================] - 19s 529ms/step - loss: 0.4667 - accuracy: 0.8383 - val_loss: 1.0244 - val_accuracy: 0.7218
# Epoch 13/50
# 36/36 [==============================] - 19s 527ms/step - loss: 0.4816 - accuracy: 0.8347 - val_loss: 0.9875 - val_accuracy: 0.7425
# Epoch 14/50
# 36/36 [==============================] - 19s 524ms/step - loss: 0.4432 - accuracy: 0.8456 - val_loss: 1.0565 - val_accuracy: 0.7348
# Epoch 15/50
# 36/36 [==============================] - 19s 524ms/step - loss: 0.4392 - accuracy: 0.8536 - val_loss: 0.9902 - val_accuracy: 0.7387
# Epoch 16/50
# 36/36 [==============================] - 19s 528ms/step - loss: 0.4786 - accuracy: 0.8343 - val_loss: 1.0493 - val_accuracy: 0.7367
# Epoch 17/50
# 36/36 [==============================] - 19s 519ms/step - loss: 0.4222 - accuracy: 0.8525 - val_loss: 1.0362 - val_accuracy: 0.7503
# Epoch 18/50
# 36/36 [==============================] - 19s 530ms/step - loss: 0.4259 - accuracy: 0.8587 - val_loss: 1.1563 - val_accuracy: 0.7289
# Epoch 19/50
# 36/36 [==============================] - 20s 542ms/step - loss: 0.4312 - accuracy: 0.8534 - val_loss: 1.0707 - val_accuracy: 0.7490
# Epoch 20/50
# 36/36 [==============================] - 19s 526ms/step - loss: 0.3780 - accuracy: 0.8701 - val_loss: 1.0233 - val_accuracy: 0.7568
# Epoch 21/50
# 36/36 [==============================] - 19s 528ms/step - loss: 0.4244 - accuracy: 0.8498 - val_loss: 1.2182 - val_accuracy: 0.7134
# Epoch 22/50
# 36/36 [==============================] - 19s 531ms/step - loss: 0.3970 - accuracy: 0.8674 - val_loss: 1.0931 - val_accuracy: 0.7581
# Epoch 23/50
# 36/36 [==============================] - 19s 519ms/step - loss: 0.3458 - accuracy: 0.8814 - val_loss: 1.0661 - val_accuracy: 0.7685
# Epoch 24/50
# 36/36 [==============================] - 19s 523ms/step - loss: 0.3492 - accuracy: 0.8814 - val_loss: 1.0786 - val_accuracy: 0.7523
# Epoch 25/50
# 36/36 [==============================] - 19s 524ms/step - loss: 0.3825 - accuracy: 0.8683 - val_loss: 1.1081 - val_accuracy: 0.7425
# Epoch 26/50
# 36/36 [==============================] - 19s 528ms/step - loss: 0.3903 - accuracy: 0.8719 - val_loss: 1.1039 - val_accuracy: 0.7588
# Epoch 27/50
# 36/36 [==============================] - 19s 522ms/step - loss: 0.3448 - accuracy: 0.8803 - val_loss: 1.1749 - val_accuracy: 0.7387
# Epoch 28/50
# 36/36 [==============================] - 19s 525ms/step - loss: 0.3609 - accuracy: 0.8765 - val_loss: 1.0610 - val_accuracy: 0.7568
# Epoch 29/50
# 36/36 [==============================] - 19s 520ms/step - loss: 0.3178 - accuracy: 0.8901 - val_loss: 1.1113 - val_accuracy: 0.7750
# Epoch 30/50
# 36/36 [==============================] - 19s 522ms/step - loss: 0.3170 - accuracy: 0.8937 - val_loss: 1.2274 - val_accuracy: 0.7458
# Epoch 31/50
# 36/36 [==============================] - 19s 527ms/step - loss: 0.3036 - accuracy: 0.8950 - val_loss: 1.1215 - val_accuracy: 0.7613
# Epoch 32/50
# 36/36 [==============================] - 19s 515ms/step - loss: 0.3290 - accuracy: 0.8921 - val_loss: 1.1244 - val_accuracy: 0.7607
# Epoch 33/50
# 36/36 [==============================] - 19s 527ms/step - loss: 0.3195 - accuracy: 0.8939 - val_loss: 1.2616 - val_accuracy: 0.7510
# Epoch 34/50
# 36/36 [==============================] - 19s 515ms/step - loss: 0.3067 - accuracy: 0.9001 - val_loss: 1.1359 - val_accuracy: 0.7613
# Epoch 35/50
# 36/36 [==============================] - 19s 516ms/step - loss: 0.3147 - accuracy: 0.8983 - val_loss: 1.2606 - val_accuracy: 0.7315
# Epoch 36/50
# 36/36 [==============================] - 18s 514ms/step - loss: 0.3584 - accuracy: 0.8785 - val_loss: 1.0904 - val_accuracy: 0.7633
# Epoch 37/50
# 36/36 [==============================] - 19s 518ms/step - loss: 0.3098 - accuracy: 0.8930 - val_loss: 1.1637 - val_accuracy: 0.7652
# Epoch 38/50
# 36/36 [==============================] - 19s 535ms/step - loss: 0.3297 - accuracy: 0.8889 - val_loss: 1.0799 - val_accuracy: 0.7711
# Epoch 39/50
# 36/36 [==============================] - 19s 539ms/step - loss: 0.2966 - accuracy: 0.9032 - val_loss: 1.1479 - val_accuracy: 0.7601
# Epoch 40/50
# 36/36 [==============================] - 19s 535ms/step - loss: 0.2648 - accuracy: 0.9083 - val_loss: 1.1801 - val_accuracy: 0.7685
# Epoch 41/50
# 36/36 [==============================] - 20s 542ms/step - loss: 0.2467 - accuracy: 0.9175 - val_loss: 1.1515 - val_accuracy: 0.7659
# Epoch 42/50
# 36/36 [==============================] - 19s 530ms/step - loss: 0.2646 - accuracy: 0.9137 - val_loss: 1.1821 - val_accuracy: 0.7750
# Epoch 43/50
# 36/36 [==============================] - 19s 532ms/step - loss: 0.2586 - accuracy: 0.9123 - val_loss: 1.1052 - val_accuracy: 0.7743
# Epoch 44/50
# 36/36 [==============================] - 19s 528ms/step - loss: 0.2418 - accuracy: 0.9184 - val_loss: 1.1503 - val_accuracy: 0.7802
# Epoch 45/50
# 36/36 [==============================] - 19s 528ms/step - loss: 0.2393 - accuracy: 0.9199 - val_loss: 1.2983 - val_accuracy: 0.7542
# Epoch 46/50
# 36/36 [==============================] - 19s 532ms/step - loss: 0.2621 - accuracy: 0.9119 - val_loss: 1.1548 - val_accuracy: 0.7840
# Epoch 47/50
# 36/36 [==============================] - 20s 543ms/step - loss: 0.2337 - accuracy: 0.9212 - val_loss: 1.1683 - val_accuracy: 0.7776
# Epoch 48/50
# 36/36 [==============================] - 19s 531ms/step - loss: 0.2739 - accuracy: 0.9028 - val_loss: 1.1163 - val_accuracy: 0.7756
# Epoch 49/50
# 36/36 [==============================] - 20s 543ms/step - loss: 0.2368 - accuracy: 0.9188 - val_loss: 1.1684 - val_accuracy: 0.7860
# Epoch 50/50
# 36/36 [==============================] - 19s 536ms/step - loss: 0.2312 - accuracy: 0.9230 - val_loss: 1.1617 - val_accuracy: 0.7840

# %%
# graph for model accuracy between training and validation
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['test', 'train'])
plt.show()
